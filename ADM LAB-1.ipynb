# %% [markdown]
# <a href="https://colab.research.google.com/github/Akshitha1330/ADM-LAB/blob/main/ADM%20LAB-1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
data = pd.read_csv('/iris.csv')
data.head()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width      species
# 0           5.1          3.5           1.4          0.2  Iris-setosa
# 1           4.9          3.0           1.4          0.2  Iris-setosa
# 2           4.7          3.2           1.3          0.2  Iris-setosa
# 3           4.6          3.1           1.5          0.2  Iris-setosa
# 4           5.0          3.6           1.4          0.2  Iris-setosa

# %%
data1=pd.read_csv('/Titanic-Dataset.csv')
data1.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
print(data1.isnull().sum())
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age            177
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Cabin          687
# Embarked         2
# dtype: int64

# %%
data1['Age'].mean()
# Out:
# 29.69911764705882

# %%
data1['Age'].fillna(data1['Age'].mean(), inplace=True)

# %%
data1.isnull().sum()
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age              0
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Cabin          687
# Embarked         2
# dtype: int64

# %%
data1['Age'].median()
# Out:
# 29.69911764705882

# %%
data1['Age'].fillna(data1['Age'].median(), inplace=True)

# %%
data1.isnull().sum()
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age              0
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Cabin          687
# Embarked         2
# dtype: int64

# %%
data1['Age'].mode()
# Out:
# 0    29.699118
# Name: Age, dtype: float64

# %%
data1['Age'].fillna(data1['Age'].mode(), inplace=True)

# %%
data1.isnull().sum()
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age              0
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Cabin          687
# Embarked         2
# dtype: int64

# %%
from sklearn.preprocessing import MinMaxScaler

# %%
scaler = MinMaxScaler()

# %%
columns_to_normalize = ['Age', 'Fare']
data1[columns_to_normalize] = scaler.fit_transform(data1[columns_to_normalize])
data1['Age']
# Out:
# 0      0.271174
# 1      0.472229
# 2      0.321438
# 3      0.434531
# 4      0.434531
#          ...
# 886    0.334004
# 887    0.233476
# 888    0.367921
# 889    0.321438
# 890    0.396833
# Name: Age, Length: 891, dtype: float64

# %%
print(data1.isnull().sum())
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age              0
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Cabin          687
# Embarked         2
# dtype: int64

# %%
data1['Cabin']
# Out:
# 0       NaN
# 1       C85
# 2       NaN
# 3      C123
# 4       NaN
#        ...
# 886     NaN
# 887     B42
# 888     NaN
# 889    C148
# 890     NaN
# Name: Cabin, Length: 891, dtype: object

# %%
data1['Cabin'].mode()
# Out:
# 0    B96 B98
# 1         G6
# Name: Cabin, dtype: object

# %%
data1['Cabin'].fillna(data1['Cabin'].mode())
# Out:
# 0      B96 B98
# 1          C85
# 2           G6
# 3         C123
# 4          NaN
#         ...
# 886        NaN
# 887        B42
# 888        NaN
# 889       C148
# 890        NaN
# Name: Cabin, Length: 891, dtype: object

# %%
data1['Cabin'].fillna(data1['Cabin'].mode()[0], inplace=True)

# %%
data1['Cabin']
# Out:
# 0      B96 B98
# 1          C85
# 2           G6
# 3         C123
# 4      B96 B98
#         ...
# 886    B96 B98
# 887        B42
# 888    B96 B98
# 889       C148
# 890    B96 B98
# Name: Cabin, Length: 891, dtype: object

# %%
data1.isnull().sum()
# Out:
# PassengerId    0
# Survived       0
# Pclass         0
# Name           0
# Sex            0
# Age            0
# SibSp          0
# Parch          0
# Ticket         0
# Fare           0
# Cabin          0
# Embarked       2
# dtype: int64

# %%
from sklearn.preprocessing import MinMaxScaler
scaler = MinMaxScaler()
columns_to_normalize = ['Age', 'Fare']

# %%
data1[columns_to_normalize] = scaler.fit_transform(data1[columns_to_normalize])

# %%
data1['Age']
# Out:
# 0      0.271174
# 1      0.472229
# 2      0.321438
# 3      0.434531
# 4      0.434531
#          ...
# 886    0.334004
# 887    0.233476
# 888    0.367921
# 889    0.321438
# 890    0.396833
# Name: Age, Length: 891, dtype: float64

# %%
data1[columns_to_normalize].head()
# Out:
#         Age      Fare
# 0  0.271174  0.014151
# 1  0.472229  0.139136
# 2  0.321438  0.015469
# 3  0.434531  0.103644
# 4  0.434531  0.015713

# %%
from sklearn.preprocessing import StandardScaler
scaler = StandardScaler()
data1[columns_to_normalize] = scaler.fit_transform(data1[columns_to_normalize])
data1[columns_to_normalize].head()
# Out:
#         Age      Fare
# 0 -0.592481 -0.502445
# 1  0.638789  0.786845
# 2 -0.284663 -0.488854
# 3  0.407926  0.420730
# 4  0.407926 -0.486337
